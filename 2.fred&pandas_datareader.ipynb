# %%
pip install fredapi
# Out:
# Collecting fredapi
#   Using cached https://files.pythonhosted.org/packages/db/82/9ca1e4a7f1b2ae057e8352cc46d016866c067a12d013fc05af0670f4291a/fredapi-0.4.3-py3-none-any.whl
# Collecting pandas (from fredapi)
#   Using cached https://files.pythonhosted.org/packages/ba/9c/55bbffd9a2c55360eb2a1da5634f553d39db9df17da037989e2215c941b4/pandas-1.3.5-cp38-cp38-win_amd64.whl
# Collecting numpy>=1.17.3; platform_machine != "aarch64" and platform_machine != "arm64" and python_version < "3.10" (from pandas->fredapi)
#   Downloading https://files.pythonhosted.org/packages/52/b4/775fed9035c738fefb005048a089441dd861762b6213164f0a39de087462/numpy-1.22.0-cp38-cp38-win_amd64.whl (14.7MB)
# Requirement already satisfied: python-dateutil>=2.7.3 in c:\users\reddl\appdata\local\programs\python\python38\lib\site-packages (from pandas->fredapi) (2.8.2)
# Collecting pytz>=2017.3 (from pandas->fredapi)
#   Using cached https://files.pythonhosted.org/packages/d3/e3/d9f046b5d1c94a3aeab15f1f867aa414f8ee9d196fae6865f1d6a0ee1a0b/pytz-2021.3-py2.py3-none-any.whl
# Requirement already satisfied: six>=1.5 in c:\users\reddl\appdata\roaming\python\python38\site-packages (from python-dateutil>=2.7.3->pandas->fredapi) (1.14.0)
# Installing collected packages: numpy, pytz, pandas, fredapi
# Successfully installed fredapi-0.4.3 numpy-1.22.0 pandas-1.3.5 pytz-2021.3
# Note: you may need to restart the kernel to use updated packages.
# WARNING: You are using pip version 19.2.3, however version 21.3.1 is available.
# You should consider upgrading via the 'python -m pip install --upgrade pip' command.

# %%
from fredapi import Fred
fred = Fred(api_key='#')
data = fred.get_series('Nasdaq100')
WTI_price=fred.get_series('DCOILWTICO', observation_start='2015-01-01')

# %%
pip install pandas_datareader --upgrade
# Out:
# Collecting pandas_datareader
#   Using cached https://files.pythonhosted.org/packages/3f/16/56c9d648b503619ebe96f726b5f642b68e299b34162ed2d6faa9d7966b7d/pandas_datareader-0.10.0-py3-none-any.whl
# Requirement already satisfied, skipping upgrade: requests>=2.19.0 in c:\users\reddl\appdata\local\programs\python\python38\lib\site-packages (from pandas_datareader) (2.24.0)
# Requirement already satisfied, skipping upgrade: pandas>=0.23 in c:\users\reddl\appdata\local\programs\python\python38\lib\site-packages (from pandas_datareader) (1.3.5)
# Collecting lxml (from pandas_datareader)
#   Downloading https://files.pythonhosted.org/packages/ce/7c/06dd0464584955e3604652b6e243e282d25a17cc38d6c9a0aff298ceff30/lxml-4.7.1-cp38-cp38-win_amd64.whl (3.7MB)
# Requirement already satisfied, skipping upgrade: certifi>=2017.4.17 in c:\users\reddl\appdata\local\programs\python\python38\lib\site-packages (from requests>=2.19.0->pandas_datareader) (2020.6.20)
# Requirement already satisfied, skipping upgrade: chardet<4,>=3.0.2 in c:\users\reddl\appdata\local\programs\python\python38\lib\site-packages (from requests>=2.19.0->pandas_datareader) (3.0.4)
# Requirement already satisfied, skipping upgrade: idna<3,>=2.5 in c:\users\reddl\appdata\local\programs\python\python38\lib\site-packages (from requests>=2.19.0->pandas_datareader) (2.10)
# Requirement already satisfied, skipping upgrade: urllib3!=1.25.0,!=1.25.1,<1.26,>=1.21.1 in c:\users\reddl\appdata\local\programs\python\python38\lib\site-packages (from requests>=2.19.0->pandas_datareader) (1.25.10)
# Requirement already satisfied, skipping upgrade: pytz>=2017.3 in c:\users\reddl\appdata\local\programs\python\python38\lib\site-packages (from pandas>=0.23->pandas_datareader) (2021.3)
# Requirement already satisfied, skipping upgrade: numpy>=1.17.3; platform_machine != "aarch64" and platform_machine != "arm64" and python_version < "3.10" in c:\users\reddl\appdata\local\programs\python\python38\lib\site-packages (from pandas>=0.23->pandas_datareader) (1.22.0)
# Requirement already satisfied, skipping upgrade: python-dateutil>=2.7.3 in c:\users\reddl\appdata\local\programs\python\python38\lib\site-packages (from pandas>=0.23->pandas_datareader) (2.8.2)
# Requirement already satisfied, skipping upgrade: six>=1.5 in c:\users\reddl\appdata\roaming\python\python38\site-packages (from python-dateutil>=2.7.3->pandas>=0.23->pandas_datareader) (1.14.0)
# Installing collected packages: lxml, pandas-datareader
# Successfully installed lxml-4.7.1 pandas-datareader-0.10.0
# Note: you may need to restart the kernel to use updated packages.
# WARNING: You are using pip version 19.2.3, however version 21.3.1 is available.
# You should consider upgrading via the 'python -m pip install --upgrade pip' command.

# %%
pip install matplotlib
# Out:
# Collecting matplotlib
#   Downloading https://files.pythonhosted.org/packages/83/a5/d079d2287ac7a6389059a0e52537dc2e2ff342580512f42f6c7844c451a0/matplotlib-3.5.1-cp38-cp38-win_amd64.whl (7.2MB)
# Collecting kiwisolver>=1.0.1 (from matplotlib)
#   Downloading https://files.pythonhosted.org/packages/30/17/5474c0fcd670f1bb2204218bf3f444e6012a97f774336022612320ab4ea4/kiwisolver-1.3.2-cp38-cp38-win_amd64.whl (52kB)
# Note: you may need to restart the kernel to use updated packages.Collecting pyparsing>=2.2.1 (from matplotlib)
#   Downloading https://files.pythonhosted.org/packages/a0/34/895006117f6fce0b4de045c87e154ee4a20c68ec0a4c9a36d900888fb6bc/pyparsing-3.0.6-py3-none-any.whl (97kB)
# Requirement already satisfied: python-dateutil>=2.7 in c:\users\reddl\appdata\local\programs\python\python38\lib\site-packages (from matplotlib) (2.8.2)
# WARNING: You are using pip version 19.2.3, however version 21.3.1 is available.
# You should consider upgrading via the 'python -m pip install --upgrade pip' command.
# Collecting cycler>=0.10 (from matplotlib)
#   Downloading https://files.pythonhosted.org/packages/5c/f9/695d6bedebd747e5eb0fe8fad57b72fdf25411273a39791cde838d5a8f51/cycler-0.11.0-py3-none-any.whl
# Collecting pillow>=6.2.0 (from matplotlib)
#   Downloading https://files.pythonhosted.org/packages/e3/fe/e9cbf297e81f7d937c168480321679acf32991046b7fdf7e2e76d88b8ed4/Pillow-9.0.0-cp38-cp38-win_amd64.whl (3.2MB)
# Requirement already satisfied: numpy>=1.17 in c:\users\reddl\appdata\local\programs\python\python38\lib\site-packages (from matplotlib) (1.22.0)
# Collecting packaging>=20.0 (from matplotlib)
#   Downloading https://files.pythonhosted.org/packages/05/8e/8de486cbd03baba4deef4142bd643a3e7bbe954a784dc1bb17142572d127/packaging-21.3-py3-none-any.whl (40kB)
# Collecting fonttools>=4.22.0 (from matplotlib)
#   Downloading https://files.pythonhosted.org/packages/c0/77/6570a4cc3f706f1afb217a1603d1b05ebf8e259d5a04256904ef2575e108/fonttools-4.28.5-py3-none-any.whl (890kB)
# Requirement already satisfied: six>=1.5 in c:\users\reddl\appdata\roaming\python\python38\site-packages (from python-dateutil>=2.7->matplotlib) (1.14.0)
# Installing collected packages: kiwisolver, pyparsing, cycler, pillow, packaging, fonttools, matplotlib
# Successfully installed cycler-0.11.0 fonttools-4.28.5 kiwisolver-1.3.2 matplotlib-3.5.1 packaging-21.3 pillow-9.0.0 pyparsing-3.0.6

# %%
pip install seaborn
# Out:
# Collecting seabornNote: you may need to restart the kernel to use updated packages.
# WARNING: You are using pip version 19.2.3, however version 21.3.1 is available.
# You should consider upgrading via the 'python -m pip install --upgrade pip' command.
#   Downloading https://files.pythonhosted.org/packages/10/5b/0479d7d845b5ba410ca702ffcd7f2cd95a14a4dfff1fde2637802b258b9b/seaborn-0.11.2-py3-none-any.whl (292kB)
# Requirement already satisfied: pandas>=0.23 in c:\users\reddl\appdata\local\programs\python\python38\lib\site-packages (from seaborn) (1.3.5)
# Requirement already satisfied: numpy>=1.15 in c:\users\reddl\appdata\local\programs\python\python38\lib\site-packages (from seaborn) (1.22.0)
# Requirement already satisfied: matplotlib>=2.2 in c:\users\reddl\appdata\local\programs\python\python38\lib\site-packages (from seaborn) (3.5.1)
# Collecting scipy>=1.0 (from seaborn)
#   Downloading https://files.pythonhosted.org/packages/b9/23/8c13a8973f5f695577f396fc2a6a920d00e91727bff173c48d03d1732a78/scipy-1.7.3-cp38-cp38-win_amd64.whl (34.2MB)
# Requirement already satisfied: pytz>=2017.3 in c:\users\reddl\appdata\local\programs\python\python38\lib\site-packages (from pandas>=0.23->seaborn) (2021.3)
# Requirement already satisfied: python-dateutil>=2.7.3 in c:\users\reddl\appdata\local\programs\python\python38\lib\site-packages (from pandas>=0.23->seaborn) (2.8.2)
# Requirement already satisfied: pillow>=6.2.0 in c:\users\reddl\appdata\local\programs\python\python38\lib\site-packages (from matplotlib>=2.2->seaborn) (9.0.0)
# Requirement already satisfied: pyparsing>=2.2.1 in c:\users\reddl\appdata\local\programs\python\python38\lib\site-packages (from matplotlib>=2.2->seaborn) (3.0.6)
# Requirement already satisfied: kiwisolver>=1.0.1 in c:\users\reddl\appdata\local\programs\python\python38\lib\site-packages (from matplotlib>=2.2->seaborn) (1.3.2)
# Requirement already satisfied: packaging>=20.0 in c:\users\reddl\appdata\local\programs\python\python38\lib\site-packages (from matplotlib>=2.2->seaborn) (21.3)
# Requirement already satisfied: cycler>=0.10 in c:\users\reddl\appdata\local\programs\python\python38\lib\site-packages (from matplotlib>=2.2->seaborn) (0.11.0)
# Requirement already satisfied: fonttools>=4.22.0 in c:\users\reddl\appdata\local\programs\python\python38\lib\site-packages (from matplotlib>=2.2->seaborn) (4.28.5)
# Requirement already satisfied: six>=1.5 in c:\users\reddl\appdata\roaming\python\python38\site-packages (from python-dateutil>=2.7.3->pandas>=0.23->seaborn) (1.14.0)
# Installing collected packages: scipy, seaborn
# Successfully installed scipy-1.7.3 seaborn-0.11.2

# %%
pip install sklearn
# Out:
# Collecting sklearnNote: you may need to restart the kernel to use updated packages.
# WARNING: You are using pip version 19.2.3, however version 21.3.1 is available.
# You should consider upgrading via the 'python -m pip install --upgrade pip' command.
#   Downloading https://files.pythonhosted.org/packages/1e/7a/dbb3be0ce9bd5c8b7e3d87328e79063f8b263b2b1bfa4774cb1147bfcd3f/sklearn-0.0.tar.gz
# Collecting scikit-learn (from sklearn)
#   Downloading https://files.pythonhosted.org/packages/50/f5/2bfd87943a29870bdbe00346c9f3b0545dd7a188201297a33189f866f04e/scikit_learn-1.0.2-cp38-cp38-win_amd64.whl (7.2MB)
# Collecting threadpoolctl>=2.0.0 (from scikit-learn->sklearn)
#   Downloading https://files.pythonhosted.org/packages/ff/fe/8aaca2a0db7fd80f0b2cf8a16a034d3eea8102d58ff9331d2aaf1f06766a/threadpoolctl-3.0.0-py3-none-any.whl
# Collecting joblib>=0.11 (from scikit-learn->sklearn)
#   Downloading https://files.pythonhosted.org/packages/3e/d5/0163eb0cfa0b673aa4fe1cd3ea9d8a81ea0f32e50807b0c295871e4aab2e/joblib-1.1.0-py2.py3-none-any.whl (306kB)
# Requirement already satisfied: scipy>=1.1.0 in c:\users\reddl\appdata\local\programs\python\python38\lib\site-packages (from scikit-learn->sklearn) (1.7.3)
# Requirement already satisfied: numpy>=1.14.6 in c:\users\reddl\appdata\local\programs\python\python38\lib\site-packages (from scikit-learn->sklearn) (1.22.0)
# Installing collected packages: threadpoolctl, joblib, scikit-learn, sklearn
#   Running setup.py install for sklearn: started
#     Running setup.py install for sklearn: finished with status 'done'
# Successfully installed joblib-1.1.0 scikit-learn-1.0.2 sklearn-0.0 threadpoolctl-3.0.0

# %%
import pandas_datareader as web
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import sklearn

# %%
df=web.DataReader('SOXL', 'yahoo', start='2015-01-01')

# %%
pd.DataFrame(df['Adj Close'])
# Out:
#             Adj Close
# Date
# 2014-12-31   2.107079
# 2015-01-02   2.107236
# 2015-01-05   1.987988
# 2015-01-06   1.852642
# 2015-01-07   1.908749
# ...               ...
# 2021-12-29  71.000000
# 2021-12-30  68.360001
# 2021-12-31  68.010002
# 2022-01-03  72.099998
# 2022-01-04  71.070000
#
# [1766 rows x 1 columns]
